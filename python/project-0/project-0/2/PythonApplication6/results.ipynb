# %% [markdown]
# ## Results
# | مقاصد سفر های داخل استانی   |   میزان تردد |
# |:----------------------------|-------------:|
# | کرمان(هفت باغ علوي)‬         |       182125 |
# | سه‌راهي راين (ماهان)‬         |       151047 |
# | حاجي آباد‬                   |       148908 |
# | ماهان (ماهان)‬               |       146649 |
# | جيرف‬                        |       143608 |
# | کرمان(جيرفت)‬                |       142114 |
# | انار (انار)‬                 |       139799 |
# | بم‬                          |       128303 |
# | ماهان (هفت باغ علوي)‬        |       123735 |
# | باغين‬                       |       121805 |
# | ماهان‬                       |       120952 |
# | ماهان (بم                   |       109596 |
# | سيرجان (سیرجان)‬             |       106742 |
# | بردسير‬                      |       105745 |
# | نيريز (سیرجان)‬              |       105337 |
# | انار‬                        |       100097 |
# | بم (سه‌راهي جيرفت            |        98791 |
# | مهريز (انار)‬                |        97998 |
# | جوزم (شهربابک)‬              |        92261 |
# | انار(انار)‬                  |        89868 |
# | کرمان‬                       |        87684 |
# | چترود (ده زيار)‬             |        83844 |
# | چترود (چترود)‬               |        83381 |
# | هوتک (چترود)‬                |        82950 |
# | سيرجان (شهربابک)‬            |        80769 |
# | گلمورتي‬                     |        79924 |
# | زرند (چترود)‬                |        79067 |
# | رودبار‬                      |        77688 |
# | کهنوج‬                       |        76811 |
# | شهربابک (انار)‬              |        76643 |
# | ماهان (سه‌راهي جيرفت         |        76526 |
# | بافت (دلفارد)‬               |        70638 |
# | رفسنجان‬                     |        69379 |
# | کرمان (جبالبارز)‬            |        68339 |
# | زرند (ده زيار)‬              |        68179 |
# | اختيار آباد‬                 |        67729 |
# | منوجان‬                      |        66938 |
# | جيرفت (جبالبارز)‬            |        66456 |
# | کوهپايه‬                     |        65768 |
# | رودان‬                       |        64944 |
# | جيرفت (دلفارد)‬              |        60975 |
# | بم (سه‌راهي راين             |        60182 |
# | كرمان‬                       |        60154 |
# | دهبکري‬                      |        57847 |
# | نوق‬                         |        56335 |
# | قلعه گنج‬                    |        55363 |
# | فارياب (خاتون‌آباد)‬          |        50843 |
# | رفسنجان (داوران)‬            |        50140 |
# | ارزوييه‬                     |        49610 |
# | زنگي آباد‬                   |        48292 |
# | جوپار‬                       |        48226 |
# | بم (بزمان                   |        48040 |
# | راور‬                        |        46703 |
# | زرند (داوران)‬               |        46253 |
# | سه‌راهي راين‬                 |        45755 |
# | زاهدان‬                      |        44239 |
# | فهرج‬                        |        43787 |
# | نرمانشير‬                    |        42917 |
# | دشتخاک‬                      |        42001 |
# | سيرجان (بافت)‬               |        41765 |
# | پاريز‬                       |        41433 |
# | بافت (بافت)‬                 |        41156 |
# | ايرانشهر (نرمانشير          |        40880 |
# | زرند‬                        |        40772 |
# | چترود‬                       |        40635 |
# | سيرجان‬                      |        40357 |
# | کرمان (نگار)‬                |        38383 |
# | جيرفت (خاتون‌آباد)‬           |        37425 |
# | سرچشمه‬                      |        36204 |
# | شهربابک‬                     |        35390 |
# | کرمان(ماهان)‬                |        34338 |
# | راور (راور)‬                 |        33961 |
# | بافت (ارزوئيه)‬              |        33180 |
# | سيرچ‬                        |        32645 |
# | جيرفت‬                       |        31861 |
# | راين‬                        |        29912 |
# | عنبرآباد‬                    |        28491 |
# | مردهک‬                       |        28406 |
# | بافت (رابر)‬                 |        27939 |
# | رابر (رابر)‬                 |        27657 |
# | ارزوئيه (ارزوئيه)‬           |        26707 |
# | فرودگاه‬                     |        26310 |
# | وکيل‌آباد (ارزوئيه)‬          |        26050 |
# | ديهوک (راور)‬                |        25823 |
# | شهربابک (شهربابک)‬           |        25353 |
# | ايرانشهر‬                    |        23542 |
# | بافت (نگار)‬                 |        23226 |
# | زهکلوت‬                      |        23077 |
# | زرند (زرند،محور سي ريز)‬     |        23060 |
# | بافق (زرند،محور سي ريز)‬     |        22341 |
# | باغين (سرآسياب)‬             |        22322 |
# | کمربندي کرمان (سرآسياب)‬     |        21108 |
# | هرات (شهربابک)‬              |        19753 |
# | در بهشت‬                     |        17815 |
# | بافت‬                        |        17420 |
# | زيارتعلي‬                    |        17107 |
# | فارياب‬                      |        15823 |
# | جيرفت (قنات ملك)‬            |        15135 |
# | رابر (قنات ملك)‬             |        14797 |
# | شهداد (شهداد)‬               |        14549 |
# | نهبندان (شهداد)‬             |        14229 |
# | سيرجان (سيرجان)‬             |        12458 |
# | بافت (سيرجان)‬               |         8622 |

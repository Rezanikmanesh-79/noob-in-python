# %% [markdown]
# # ترافیک نقاط
#
# | نقطه            |   ترافیک |
# |:----------------|---------:|
# | کرمان           | 50270498 |
# | سيرجان          | 36636456 |
# | ماهان           | 25274023 |
# | جيرفت           | 24922539 |
# | باغين           | 22392379 |
# | شهربابک         | 22066134 |
# | رفسنجان         | 19263447 |
# | کهنوج           | 17514489 |
# | بم              | 16043597 |
# | بافت            | 15048103 |
# | چترود           | 14826896 |
# | زرند            | 14821715 |
# | انار            | 13586430 |
# | سه راهي راين    | 13019322 |
# | بردسير          | 11174702 |
# | نيريز           |  7156042 |
# | زاهدان          |  6523852 |
# | مهريز           |  5735795 |
# | حاجي آباد       |  5411304 |
# | هوتک            |  5246074 |
# | سرچشمه          |  4965706 |
# | اختيار آباد     |  4891017 |
# | جوپار           |  4505656 |
# | رودبار          |  4077770 |
# | زهکلوت          |  3803287 |
# | فارياب          |  3656486 |
# | جوزم            |  3470614 |
# | كرمان           |  3313443 |
# | نوق             |  3256114 |
# | زنگي آباد       |  3167578 |
# | منوجان          |  3127898 |
# | قلعه گنج        |  2904004 |
# | ايرانشهر        |  2574194 |
# | کوهپايه         |  2532319 |
# | جاده قديم کرمان |  2526990 |
# | ارزوئيه         |  2454597 |
# | رودان           |  2373937 |
# | عنبرآباد        |  2203594 |
# | راور            |  2154032 |
# | ارزوييه         |  2083822 |
# | جاده قديم ماهان |  2072958 |
# | نرمانشير        |  2032624 |
# | فهرج            |  2032624 |
# | دهبکري          |  1953331 |
# | دشتخاک          |  1917751 |
# | رابر            |  1816467 |
# | پاريز           |  1568686 |
# | مردهک           |  1373227 |
# | بافق            |  1268216 |
# | کمربندي سيرجان  |  1149105 |
# | کمربندي باغين   |  1056184 |
# | ديهوک           |   993172 |
# | فرودگاه         |   922195 |
# | هرات            |   886598 |
# | وکيل‌آباد        |   805529 |
# | درب بهشت        |   602429 |
# | سيرج            |   504109 |
# | سيرچ            |   491482 |
# | گلمورتي         |   425627 |
# | بلوک            |   414716 |
# | زيارتعلي        |   403348 |
# | جيرف            |   361308 |
# | شهداد           |   270008 |
# | نهبندان         |   270008 |
# | نگار            |    85184 |
# | بهرامجرد        |    85184 |
# | در بهشت         |    33289 |

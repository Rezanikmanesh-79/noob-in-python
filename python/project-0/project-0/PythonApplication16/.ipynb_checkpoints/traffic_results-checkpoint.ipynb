# %% [markdown]
# # ترافیک نقاط
#
# | نقطه            |   ترافیک |
# |:----------------|---------:|
# | جيرفت           |  3061637 |
# | کرمان           |  3042908 |
# | سيرجان          |  2912170 |
# | ماهان           |  2071373 |
# | کهنوج           |  1944078 |
# | انار            |  1647453 |
# | بافت            |  1574473 |
# | چترود           |  1485521 |
# | باغين           |  1463509 |
# | شهربابک         |  1300970 |
# | بم              |  1282850 |
# | رفسنجان         |  1240389 |
# | ماهان           |  1173044 |
# | زرند            |  1031863 |
# | بم              |   726229 |
# | سيرجان          |   726001 |
# | بردسير          |   704471 |
# | کرمان           |   653569 |
# | بافت            |   640163 |
# | شهربابک         |   625799 |
# | زرند            |   624990 |
# | رودبار          |   597676 |
# | جيرفت           |   485523 |
# | يزد             |   482563 |
# | فارياب          |   456204 |
# | حاجي آباد       |   453288 |
# | زاهدان          |   447886 |
# | چترود           |   428037 |
# | عنبرآباد        |   409392 |
# | زهکلوت          |   400573 |
# | سه‌راهي راين     |   390367 |
# | جاده قديم کرمان |   372258 |
# | راين            |   356518 |
# | سه‌راهي جيرفت)   |   333331 |
# | قطروئيه         |   312373 |
# | جاده قديم ماهان |   309617 |
# | جيرف            |   307642 |
# | فهرج            |   303190 |
# | سرچشمه          |   292931 |
# | منوجان          |   283261 |
# | مهريز           |   274277 |
# | انار            |   274277 |
# | كرمان           |   263549 |
# | سه‌راهي راين     |   262126 |
# | راور            |   251367 |
# | مهريز           |   238193 |
# | جوزم            |   237566 |
# | جوپار           |   237270 |
# | جوزم            |   221581 |
# | گلمورتي         |   220983 |
# | نيريز           |   219924 |
# | نيريز           |   203393 |
# | دشتخاک          |   192706 |
# | ارزوئيه         |   191371 |
# | ارزوئيه         |   188363 |
# | نرمانشير        |   188267 |
# | سه راهي راين    |   187435 |
# | سه‌راهي راين)    |   187236 |
# | جبالبارز        |   181087 |
# | بم)             |   175535 |
# | ديهوک           |   169364 |
# | دلفارد          |   168982 |
# | كرمان           |   166304 |
# | دهبکري          |   164396 |
# | فارياب          |   160488 |
# | قلعه گنج        |   155836 |
# | کوهپايه         |   153349 |
# | بلوک            |   131937 |
# | ايرانشهر        |   131256 |
# | مردهک           |   127561 |
# | رابر            |   116948 |
# | درب بهشت        |   116355 |
# | رستم آباد       |   114658 |
# | بزمان           |   114658 |
# | رودان           |   108488 |
# | رابر            |   106897 |
# | ارزوييه         |   101941 |
# | سرچشمه          |    99434 |
# | جوپار           |    99141 |
# | کمربندي سيرجان  |    98981 |
# | بافق            |    96846 |
# | پاريز           |    95856 |
# | ايرانشهر        |    95689 |
# | بزمان)          |    95689 |
# | نرمانشير)       |    95331 |
# | در بهشت         |    94785 |
# | بافق            |    93552 |
# | نوق             |    86420 |
# |                 |    82486 |
# | شهر             |    81908 |
# | هرات            |    81423 |
# | کمربندي کرمان   |    70072 |
# | باغين           |    70072 |
# | فرودگاه         |    69660 |
# | رفسنجان         |    69634 |
# | کمربندي کرمان   |    63994 |
# | نهبندان         |    59191 |
# | شهداد           |    59191 |
# | شهداد           |    58553 |
# | نهبندان         |    58553 |
# | سيرچ            |    58403 |
# | سيرج            |    58357 |
# | وکيل آباد       |    52438 |
# | وکيل آباد       |    51759 |
# | راور            |    48637 |
# | WIM)            |    48235 |
# | وکيل‌آباد        |    43528 |
# | –دشتخاک         |    41532 |
# | از              |    41532 |
# | سه              |    41532 |
# | راهي            |    41532 |
# | دشتخاک)         |    41532 |
# | هرات            |    41524 |
# | بابک            |    40954 |
# | –هرات           |    40954 |
# | بابک)           |    40954 |
# | وکيل‌آباد        |    39871 |
# | ديهوک           |    37041 |
# | هوتک            |    36236 |
# | زيارتعلي        |    33826 |
# | اختيار آباد     |     8735 |
# | زنگي آباد       |     5715 |
# | کمربندي باغين   |     4365 |
# | کمربندي جوپار   |     3282 |

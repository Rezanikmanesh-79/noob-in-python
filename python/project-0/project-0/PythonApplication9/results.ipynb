# %% [markdown]
# ## Results
#
# | نقطه            |   تعداد تکرار |
# |:----------------|--------------:|
# | جيرفت           |            12 |
# | کرمان           |            10 |
# | بافت            |             9 |
# | سيرجان          |             8 |
# | کهنوج           |             6 |
# | شهربابک         |             6 |
# | زرند            |             5 |
# | رفسنجان         |             5 |
# | چترود           |             4 |
# | ماهان           |             4 |
# | باغين           |             4 |
# | بم              |             4 |
# | فارياب          |             4 |
# | انار            |             3 |
# | قلعه گنج        |             3 |
# | سه‌راهي راين     |             2 |
# | راور            |             2 |
# | ارزوئيه         |             2 |
# | رابر            |             2 |
# | بردسير          |             2 |
# | ايرانشهر        |             2 |
# | عنبرآباد        |             2 |
# | سرچشمه          |             2 |
# | منوجان          |             2 |
# | جوپار           |             1 |
# | جاده قديم ماهان |             1 |
# | شهداد           |             1 |
# | راين            |             1 |
# | جاده قديم کرمان |             1 |
# | نهبندان         |             1 |
# | کوهپايه         |             1 |
# | سه راهي راين    |             1 |
# | کمربندي باغين   |             1 |
# | ديهوک           |             1 |
# | سيرج            |             1 |
# | کمربندي کرمان   |             1 |
# | کمربندي جوپار   |             1 |
# | اختيار آباد     |             1 |
# | زنگي آباد       |             1 |
# | هوتک (چترود)    |             1 |
# | وکيل‌آباد        |             1 |
# | ارزوييه         |             1 |
# | نگار            |             1 |
# | بهرامجرد        |             1 |
# | نرمانشير        |             1 |
# | فهرج            |             1 |
# | زاهدان          |             1 |
# | درب بهشت        |             1 |
# | دهبکري          |             1 |
# | فرودگاه         |             1 |
# | مردهک           |             1 |
# | راين            |             1 |
# | مهريز           |             1 |
# | نوق             |             1 |
# | دشتخاک          |             1 |
# | بافق            |             1 |
# | کمربندي سيرجان  |             1 |
# | حاجي آباد       |             1 |
# | نيريز           |             1 |
# | پاريز           |             1 |
# | جوزم            |             1 |
# | هرات            |             1 |
# | رودبار          |             1 |
# | بلوک            |             1 |
# | زهکلوت          |             1 |
# | رودان           |             1 |
# | زيارتعلي        |             1 |

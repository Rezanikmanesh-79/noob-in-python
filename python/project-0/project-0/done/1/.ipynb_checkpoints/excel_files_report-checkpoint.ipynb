# %% [markdown]
# |    | سال        |   تعداد تعداد مسیرها |
# |---:|:-----------|---------------------:|
# |  0 | Daily Data |                    0 |
# |  1 | 1395       |                   74 |
# |  2 | 1396       |                   94 |
# |  3 | 1397       |                  103 |
# |  4 | 1398       |                  120 |
# |  5 | 1399       |                  123 |
# |  6 | 1400       |                  137 |
# |  7 | 1401       |                   68 |

# %% [markdown]
# ## Results
# | نام محور ها                                    |            میزان تردد |
# |:-----------------------------------------------|----------------------:|
# | 453958 ‫شهربابک - سيرجان‬                        |                358121 |
# | 453654 ‫کهنوج - جيرف‬                            |                353669 |
# | 453908 ‫سيرجان - شهربابک‬                        |                298254 |
# | 453153 ‫باغين - کرمان‬                           |                297282 |
# | 453517 ‫بم - زاهدان‬                             |                295489 |
# | 453567 ‫زاهدان - بم‬                             |                292321 |
# | 453254 ‫ماهان - کرمان(هفت باغ علوي)‬             |                286610 |
# | 453654 ‫کهنوج - جيرفت‬                           |                275962 |
# | 453953 ‫نيريز - سيرجان (سیرجان)‬                 |                272965 |
# | 453152 ‫ماهان - سه‌راهي راين (ماهان)‬             |                264873 |
# | 453604 ‫جيرفت - کهنوج‬                           |                260773 |
# | 453451 ‫سيرجان - بردسير‬                         |                253883 |
# | 453102 ‫سه‌راهي راين - ماهان (ماهان)‬             |                249068 |
# | 453751 ‫رفسنجان - باغين‬                         |                242389 |
# | 453401 ‫بردسير - سيرجان‬                         |                241693 |
# | 453204 ‫کرمان - ماهان (هفت باغ علوي)‬            |                238531 |
# | 453247 ‫کرمان - هوتک (چترود)‬                    |                234336 |
# | 453620 ‫جيرفت - کرمان(جيرفت)‬                    |                228369 |
# | 453701 ‫باغين - رفسنجان‬                         |                228326 |
# | 453753 ‫مهريز - انار (انار)‬                     |                222206 |
# | 453162 ‫جاده قديم کرمان - ماهان‬                 |                212369 |
# | 454202 ‫رودبار - گلمورتي‬                        |                209478 |
# | 454252 ‫گلمورتي - رودبار‬                        |                206656 |
# | 453651 ‫باغين - بردسير‬                          |                202185 |
# | 453703 ‫انار - مهريز (انار)‬                     |                201380 |
# | 453901 ‫سيرجان - حاجي آباد‬                      |                199816 |
# | 454218 ‫کهنوج - جيرفت‬                           |                199424 |
# | 453249 ‫کرمان - چترود‬                           |                199002 |
# | 454268 ‫جيرفت - کهنوج‬                           |                198186 |
# | 453903 ‫سيرجان - نيريز (سیرجان)‬                 |                196759 |
# | 453295 ‫اختيار آباد - کرمان‬                     |                195822 |
# | 453601 ‫بردسير - باغين‬                          |                194776 |
# | 453297 ‫هوتک (چترود) - کرمان‬                    |                192098 |
# | 453165 ‫زرند - چترود (ده زيار)‬                  |                191278 |
# | 453245 ‫کرمان - اختيار آباد‬                     |                189804 |
# | 453103 ‫کرمان - باغين‬                           |                188678 |
# | 453951 ‫حاجي آباد - سيرجان‬                      |                185525 |
# | 453160 ‫زرند - چترود (چترود)‬                    |                185199 |
# | 453752 ‫رفسنجان - انار‬                          |                181356 |
# | 453115 ‫چترود - زرند (ده زيار)‬                  |                179362 |
# | 453110 ‫چترود - زرند (چترود)‬                    |                171971 |
# | 453252 ‫بم - ماهان (سه‌راهي جيرفت - سه‌راهي راين)‬ |                166135 |
# | 453707 ‫رفسنجان - سرچشمه‬                        |                149632 |
# | 453602 ‫جيرفت - کرمان (جبالبارز)‬                |                148159 |
# | 453980 ‫سيرجان - شهربابک (شهربابک)‬              |                145877 |
# | 453652 ‫کرمان - جيرفت (جبالبارز)‬                |                144698 |
# | 454202 ‫ رودبار - زهکلوت‬                        |                142481 |
# | 454252 ‫زهکلوت - رودبار‬                         |                141752 |
# | 453605 ‫جيرفت - بافت (دلفارد)‬                   |                139124 |
# | 454272 ‫عنبرآباد - جيرفت‬                        |                136729 |
# | 453202 ‫ماهان - بم (سه‌راهي راين - سه‌راهي جيرفت)‬ |                136661 |
# | 453296 ‫زنگي آباد - کرمان‬                       |                135839 |
# | 454103 ‫شهربابک - جوزم (شهربابک)‬                |                135486 |
# | 453705 ‫رفسنجان - نوق‬                           |                134591 |
# | 453954 ‫بافت - سيرجان (سيرجان)‬                  |                134302 |
# | 453755 ‫نوق - رفسنجان‬                           |                128395 |
# | 453246 ‫کرمان - زنگي آباد‬                       |                128274 |
# | 453605 ‫جيرفت - بافت (پليس‌راه)‬                  |                127518 |
# | 453757 ‫سرچشمه - رفسنجان‬                        |                125448 |
# | 454153 ‫جوزم - شهربابک (شهربابک)‬                |                124688 |
# | 453904 ‫سيرجان - بافت (سيرجان)‬                  |                121984 |
# | 453112 ‫جاده قديم ماهان - كرمان‬                 |                121284 |
# | 454222 ‫جيرفت - عنبرآباد‬                        |                118950 |
# | 454264 ‫منوجان - کهنوج‬                          |                116037 |
# | 453754 ‫شهربابک - انار(انار)‬                    |                115077 |
# | 453610 ‫جيرفت - فارياب (خاتون‌آباد)‬              |                114468 |
# | 454204 ‫کهنوج - قلعه گنج‬                        |                111676 |
# | 453299 ‫چترود - کرمان‬                           |                111239 |
# | 454254 ‫قلعه گنج - کهنوج‬                        |                109789 |
# | 453502 ‫ايرانشهر - بم (بزمان - نرمانشير)‬        |                107304 |
# | 453552 ‫بم - ايرانشهر (نرمانشير - بزمان)‬        |                106139 |
# | 453655 ‫بافت - جيرفت (پليس‌راه)‬                  |                106067 |
# | 454214 ‫کهنوج - منوجان‬                          |                101715 |
# | 453610 ‫جيرفت - فارياب (کريم آباد)‬              |                 98902 |
# | 453930 ‫شهربابک - سيرجان (شهربابک)‬              |                 98626 |
# | 453652 ‫کرمان - جيرفت (پليس‌راه)‬                 |                 97463 |
# | 453164 ‫کوهپايه - کرمان‬                         |                 96638 |
# | 453154 ‫كرمان جوپار‬                             |                 94157 |
# | 453114 ‫کرمان - کوهپايه‬                         |                 94092 |
# | 453104 ‫جوپار - کرمان‬                           |                 93340 |
# | 453602 ‫جيرفت - کرمان (پليس‌راه)‬                 |                 92011 |
# | 453927 ‫کمربندي سيرجان - شهربابک‬                |                 91871 |
# | 453802 ‫زرند - رفسنجان (داوران)‬                 |                 91583 |
# | 453704 ‫انار - شهربابک (انار)‬                   |                 90557 |
# | 453660 ‫فارياب - جيرفت (خاتون‌آباد)‬              |                 87505 |
# | 453852 ‫رفسنجان - زرند (داوران)‬                 |                 86732 |
# | 454253 ‫رودان - کهنوج‬                           |                 86478 |
# | 453932 ‫بافت - سيرجان (بافت)‬                    |                 86373 |
# | 453503 ‫نرمانشير - فهرج‬                         |                 86358 |
# | 453655 ‫بافت - جيرفت (دلفارد)‬                   |                 85726 |
# | 453982 ‫سيرجان - بافت (بافت)‬                    |                 85633 |
# | 454157 ‫شهربابک - سرچشمه‬                        |                 85029 |
# | 454203 ‫کهنوج - رودان‬                           |                 84587 |
# | 453311 ‫بافت - ارزوييه‬                          |                 84238 |
# | 453361 ‫ارزوييه - بافت‬                          |                 82876 |
# | 453294 ‫کمربندي جوپار - باغين‬                   |                 79994 |
# | 453161 ‫راين - سه‌راهي راين‬                      |                 78497 |
# | 453111 ‫سه‌راهي راين - راين‬                      |                 75714 |
# | 453803 ‫زرند - دشتخاک‬                           |                 75480 |
# | 453853 ‫دشتخاک - زرند‬                           |                 75072 |
# | 453653 ‫دهبکري - جيرفت‬                          |                 68865 |
# | 453244 ‫کمربندي باغين - جوپار‬                   |                 68245 |
# | 453603 ‫جيرفت - دهبکري‬                          |                 67175 |
# | 454107 ‫سرچشمه - شهربابک‬                        |                 65978 |
# | 453699 ‫راين- جيرفت‬                             |                 65307 |
# | 453453 ‫بافت - کرمان (نگار)‬                     |                 65176 |
# | 453660 ‫فارياب - جيرفت (کريم آباد)‬              |                 64834 |
# | 453301 ‫بافت - ارزوئيه (ارزوئيه)‬                |                 64263 |
# | 453351 ‫ارزوئيه - بافت (ارزوئيه)‬                |                 64262 |
# | 454215 ‫زهکلوت - ايرانشهر‬                       |                 61608 |
# | 454265 ‫ايرانشهر - زهکلوت‬                       |                 60225 |
# | 453981 ‫پاريز - سيرجان‬                          |                 60087 |
# | 453931 ‫سيرجان - پاريز‬                          |                 58929 |
# | 453403 ‫کرمان - بافت (نگار)‬                     |                 57846 |
# | 453649 ‫جيرفت - راين‬                            |                 55950 |
# | 453353 ‫بافت - رابر (رابر)‬                      |                 54836 |
# | 453619 ‫عنبرآباد - مردهک‬                        |                 53721 |
# | 453669 ‫مردهک - عنبرآباد‬                        |                 53263 |
# | 453553 ‫فهرج - نرمانشير‬                         |                 53046 |
# | 453303 ‫رابر - بافت (رابر)‬                      |                 51634 |
# | 453854 ‫بافق - زرند (زرند،محور سي ريز)‬          |                 48545 |
# | 454154 ‫هرات - شهربابک (شهربابک)‬                |                 46949 |
# | 453203 ‫کرمان - سيرچ‬                            |                 46845 |
# | 453804 ‫زرند - بافق (زرند،محور سي ريز)‬          |                 46777 |
# | 453302 ‫ارزوئيه - وکيل‌آباد (ارزوئيه)‬            |                 46480 |
# | 454217 ‫بلوک - فارياب‬                           |                 44624 |
# | 453801 ‫چترود - راور‬                            |                 44325 |
# | 453454 ‫بهرامجرد - نگار‬                         |                 44211 |
# | 453851 ‫راور - چترود‬                            |                 43957 |
# | 453253 ‫سيرج - کرمان‬                            |                 42717 |
# | 453702 ‫انار - رفسنجان‬                          |                 42183 |
# | 453352 ‫وکيل‌آباد - ارزوئيه (ارزوئيه)‬            |                 41965 |
# | 453251 ‫ديهوک - راور (راور)‬                     |                 41822 |
# | 454267 ‫فارياب - بلوک‬                           |                 38815 |
# | 453611 ‫جيرفت - فرودگاه‬                         |                 38543 |
# | 453661 ‫فرودگاه - جيرفت‬                         |                 37526 |
# | 453404 ‫نگار - بهرامجرد‬                         |                 36989 |
# | 453256 ‫کمربندي کرمان - باغين (سرآسياب)‬         |                 33107 |
# | 453505 ‫بم - ماهان (بم - سه‌راهي جيرفت)‬          |                 32427 |
# | 453662 ‫بافت - در بهشت‬                          |                 32089 |
# | 453201 ‫راور - ديهوک (راور)‬                     |                 31491 |
# | 454263 ‫فارياب - کهنوج‬                          |                 30714 |
# | 454213 ‫کهنوج - فارياب‬                          |                 30192 |
# | 454219 ‫قلعه گنج - منوجان‬                       |                 28554 |
# | 454269 ‫منوجان - قلعه گنج‬                       |                 27860 |
# | 453662 ‫بافت - درب بهشت‬                         |                 27676 |
# | 453206 ‫باغين - کمربندي کرمان (سرآسياب)‬         |                 27472 |
# | 453205 ‫سه راهي راين - کرمان(ماهان)‬             |                 27110 |
# | 453363 ‫جيرفت - رابر (قنات ملك)‬                 |                 17306 |
# | 454104 ‫شهربابک - هرات (شهربابک)‬                |                 16314 |
# | 454266 ‫زيارتعلي - فارياب‬                       |                 14714 |
# | 454216 ‫فارياب - زيارتعلي‬                       |                 14370 |
# | 453612 ‫درب بهشت - بافت‬                         |                 14143 |
# | 453555 ‫ماهان - بم (سه‌راهي جيرفت - بم)‬          |                 11168 |
# | 453113 ‫شهداد - نهبندان (شهداد)‬                 |                  9687 |
# | 453163 ‫نهبندان - شهداد (شهداد)‬                 |                  9390 |
# | 454271 ‫بافت - جيرفت‬                            |                  8927 |
# | 454221 ‫جيرفت - بافت‬                            |                  8667 |
# | 453313 ‫رابر - جيرفت (قنات ملك)‬                 |                  8438 |
# | 454220 ‫قلعه گنج - ايرانشهر‬                     |                  7737 |
# | 454270 ‫ايرانشهر - قلعه گنج‬                     |                  2875 |

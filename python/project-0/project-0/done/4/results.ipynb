# %% [markdown]
# ## Results
# | نام نقطاط              |            میزان تردد |
# |:-----------------------|----------------------:|
# | 453153 ‫باغين           |               4816807 |
# | 453103 ‫کرمان           |               4537234 |
# | 453254 ‫ماهان           |               4374957 |
# | 453204 ‫کرمان           |               4348339 |
# | 453958 ‫شهربابک         |               3972479 |
# | 453654 ‫کهنوج           |               3670928 |
# | 453908 ‫سيرجان          |               3650576 |
# | 453604 ‫جيرفت           |               3536083 |
# | 453953 ‫نيريز           |               3514949 |
# | 453903 ‫سيرجان          |               3414902 |
# | 453152 ‫ماهان           |               3379410 |
# | 453567 ‫زاهدان          |               3329642 |
# | 453451 ‫سيرجان          |               3157389 |
# | 453102 ‫سه‌راهي راين     |               3036910 |
# | 453753 ‫مهريز           |               3023979 |
# | 453517 ‫بم              |               2974927 |
# | 453401 ‫بردسير          |               2954858 |
# | 453620 ‫جيرفت           |               2925201 |
# | 453751 ‫رفسنجان         |               2915648 |
# | 453701 ‫باغين           |               2727650 |
# | 453901 ‫سيرجان          |               2621677 |
# | 453951 ‫حاجي آباد       |               2618795 |
# | 453249 ‫کرمان           |               2608503 |
# | 453247 ‫کرمان           |               2567642 |
# | 453703 ‫انار            |               2525296 |
# | 453297 ‫هوتک (چترود)    |               2499665 |
# | 453162 ‫جاده قديم کرمان |               2446885 |
# | 453295 ‫اختيار آباد     |               2409168 |
# | 453651 ‫باغين           |               2365019 |
# | 453160 ‫زرند            |               2347791 |
# | 453752 ‫رفسنجان         |               2338209 |
# | 453702 ‫انار            |               2324345 |
# | 453245 ‫کرمان           |               2319344 |
# | 453601 ‫بردسير          |               2318351 |
# | 453165 ‫زرند            |               2300338 |
# | 453110 ‫چترود           |               2196076 |
# | 453252 ‫بم              |               2116897 |
# | 453112 ‫جاده قديم ماهان |               2014647 |
# | 453115 ‫چترود           |               2006383 |
# | 453980 ‫سيرجان          |               1848525 |
# | 454252 ‫زهکلوت          |               1764060 |
# | 454202 ‫ رودبار         |               1762104 |
# | 454103 ‫شهربابک         |               1759877 |
# | 453299 ‫چترود           |               1757597 |
# | 453202 ‫ماهان           |               1707068 |
# | 453705 ‫رفسنجان         |               1611371 |
# | 454153 ‫جوزم            |               1600002 |
# | 453930 ‫شهربابک         |               1582249 |
# | 453505 ‫بم              |               1580355 |
# | 453296 ‫زنگي آباد       |               1557341 |
# | 453755 ‫نوق             |               1537073 |
# | 454264 ‫منوجان          |               1525713 |
# | 453246 ‫کرمان           |               1501094 |
# | 453555 ‫ماهان           |               1471999 |
# | 453704 ‫انار            |               1470227 |
# | 453605 ‫جيرفت           |               1461884 |
# | 453754 ‫شهربابک         |               1458980 |
# | 453757 ‫سرچشمه          |               1388811 |
# | 453707 ‫رفسنجان         |               1386936 |
# | 454214 ‫کهنوج           |               1344270 |
# | 453655 ‫بافت            |               1339903 |
# | 453954 ‫بافت            |               1335669 |
# | 454254 ‫قلعه گنج        |               1318494 |
# | 453652 ‫کرمان           |               1302900 |
# | 453904 ‫سيرجان          |               1291368 |
# | 454204 ‫کهنوج           |               1290731 |
# | 453602 ‫جيرفت           |               1260804 |
# | 453114 ‫کرمان           |               1231279 |
# | 453802 ‫زرند            |               1226772 |
# | 453164 ‫کوهپايه         |               1225629 |
# | 453610 ‫جيرفت           |               1223918 |
# | 453154 ‫كرمان جوپار‬     |               1203120 |
# | 453502 ‫ايرانشهر        |               1200467 |
# | 454253 ‫رودان           |               1175775 |
# | 453852 ‫رفسنجان         |               1172195 |
# | 453104 ‫جوپار           |               1137519 |
# | 454203 ‫کهنوج           |               1123857 |
# | 453927 ‫کمربندي سيرجان  |               1112645 |
# | 453552 ‫بم              |               1098494 |
# | 454157 ‫شهربابک         |               1024806 |
# | 453244 ‫کمربندي باغين   |               1022905 |
# | 453311 ‫بافت            |               1020467 |
# | 453503 ‫نرمانشير        |               1007684 |
# | 453294 ‫کمربندي جوپار   |               1004974 |
# | 453982 ‫سيرجان          |                998664 |
# | 454107 ‫سرچشمه          |                998516 |
# | 453361 ‫ارزوييه         |                997294 |
# | 453161 ‫راين            |                967407 |
# | 453553 ‫فهرج            |                958683 |
# | 453932 ‫بافت            |                958300 |
# | 453653 ‫دهبکري          |                957173 |
# | 453803 ‫زرند            |                947529 |
# | 453111 ‫سه‌راهي راين     |                945635 |
# | 453603 ‫جيرفت           |                935826 |
# | 453853 ‫دشتخاک          |                908435 |
# | 453453 ‫بافت            |                820673 |
# | 453351 ‫ارزوئيه         |                803532 |
# | 453699 ‫راين            |                803250 |
# | 453301 ‫بافت            |                790857 |
# | 453649 ‫جيرفت           |                790850 |
# | 453403 ‫کرمان           |                771106 |
# | 453981 ‫پاريز           |                763898 |
# | 453205 ‫سه راهي راين    |                760516 |
# | 453931 ‫سيرجان          |                755525 |
# | 453660 ‫فارياب          |                753723 |
# | 453619 ‫عنبرآباد        |                665113 |
# | 453669 ‫مردهک           |                661689 |
# | 453353 ‫بافت            |                646925 |
# | 453854 ‫بافق            |                630083 |
# | 454268 ‫جيرفت           |                628446 |
# | 453303 ‫رابر            |                599206 |
# | 453804 ‫زرند            |                596532 |
# | 453801 ‫چترود           |                592538 |
# | 454154 ‫هرات            |                571756 |
# | 454218 ‫کهنوج           |                564249 |
# | 453851 ‫راور            |                530111 |
# | 453256 ‫کمربندي کرمان   |                506671 |
# | 453253 ‫سيرج            |                488652 |
# | 453201 ‫راور            |                480486 |
# | 453251 ‫ديهوک           |                475908 |
# | 453203 ‫کرمان           |                475417 |
# | 453611 ‫جيرفت           |                455861 |
# | 453206 ‫باغين           |                439946 |
# | 453661 ‫فرودگاه         |                439066 |
# | 454272 ‫عنبرآباد        |                424668 |
# | 453352 ‫وکيل‌آباد        |                390773 |
# | 454263 ‫فارياب          |                388484 |
# | 453302 ‫ارزوئيه         |                385151 |
# | 454213 ‫کهنوج           |                375878 |
# | 454222 ‫جيرفت           |                373743 |
# | 453612 ‫درب بهشت        |                309967 |
# | 453662 ‫بافت            |                306412 |
# | 454104 ‫شهربابک         |                285529 |
# | 453363 ‫جيرفت           |                259988 |
# | 453313 ‫رابر            |                250966 |
# | 454217 ‫بلوک            |                214281 |
# | 454202 ‫رودبار          |                209478 |
# | 454252 ‫گلمورتي         |                206656 |
# | 454266 ‫زيارتعلي        |                195827 |
# | 454216 ‫فارياب          |                194281 |
# | 454267 ‫فارياب          |                182789 |
# | 453163 ‫نهبندان         |                132567 |
# | 453113 ‫شهداد           |                129188 |
# | 454269 ‫منوجان          |                 79635 |
# | 454219 ‫قلعه گنج        |                 73410 |
# | 454215 ‫زهکلوت          |                 72493 |
# | 454265 ‫ايرانشهر        |                 71183 |
# | 454271 ‫بافت            |                 61397 |
# | 454221 ‫جيرفت           |                 57809 |
# | 453454 ‫بهرامجرد        |                 44211 |
# | 453404 ‫نگار            |                 36989 |
# | 454220 ‫قلعه گنج        |                 24273 |
# | 454270 ‫ايرانشهر        |                  9552 |

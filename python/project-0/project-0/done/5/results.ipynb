# %% [markdown]
# ## Results
# | نام محور ها                                    |            انحراف معیار |
# |:-----------------------------------------------|------------------------:|
# | 453153 ‫باغين - کرمان‬                           |             1049.49     |
# | 453505 ‫بم - ماهان (بم - سه‌راهي جيرفت)‬          |              941.939    |
# | 453202 ‫ماهان - بم (سه‌راهي راين - سه‌راهي جيرفت)‬ |              833.96     |
# | 453103 ‫کرمان - باغين‬                           |              819.099    |
# | 453297 ‫هوتک (چترود) - کرمان‬                    |              594.732    |
# | 453299 ‫چترود - کرمان‬                           |              495.921    |
# | 453649 ‫جيرفت - راين‬                            |              488.831    |
# | 453654 ‫کهنوج - جيرفت‬                           |              474.942    |
# | 453102 ‫سه‌راهي راين - ماهان (ماهان)‬             |              444.727    |
# | 453249 ‫کرمان - چترود‬                           |              424.39     |
# | 453111 ‫سه‌راهي راين - راين‬                      |              405.716    |
# | 454254 ‫قلعه گنج - کهنوج‬                        |              392.776    |
# | 454253 ‫رودان - کهنوج‬                           |              380.092    |
# | 453908 ‫سيرجان - شهربابک‬                        |              356.758    |
# | 454204 ‫کهنوج - قلعه گنج‬                        |              352.226    |
# | 454203 ‫کهنوج - رودان‬                           |              345.909    |
# | 453853 ‫دشتخاک - زرند‬                           |              328.985    |
# | 454107 ‫سرچشمه - شهربابک‬                        |              317.175    |
# | 453702 ‫انار - رفسنجان‬                          |              315.094    |
# | 453752 ‫رفسنجان - انار‬                          |              313.114    |
# | 453204 ‫کرمان - ماهان (هفت باغ علوي)‬            |              310.583    |
# | 453555 ‫ماهان - بم (سه‌راهي جيرفت - بم)‬          |              306.573    |
# | 453517 ‫بم - زاهدان‬                             |              305.171    |
# | 453604 ‫جيرفت - کهنوج‬                           |              290.904    |
# | 453161 ‫راين - سه‌راهي راين‬                      |              285.109    |
# | 453303 ‫رابر - بافت (رابر)‬                      |              283.66     |
# | 453247 ‫کرمان - هوتک (چترود)‬                    |              283.658    |
# | 453751 ‫رفسنجان - باغين‬                         |              281.2      |
# | 453901 ‫سيرجان - حاجي آباد‬                      |              273.833    |
# | 453803 ‫زرند - دشتخاک‬                           |              268.317    |
# | 453699 ‫راين- جيرفت‬                             |              265.806    |
# | 453701 ‫باغين - رفسنجان‬                         |              260.821    |
# | 454104 ‫شهربابک - هرات (شهربابک)‬                |              244.32     |
# | 453754 ‫شهربابک - انار(انار)‬                    |              242.577    |
# | 453707 ‫رفسنجان - سرچشمه‬                        |              240.922    |
# | 453704 ‫انار - شهربابک (انار)‬                   |              240.894    |
# | 454268 ‫جيرفت - کهنوج‬                           |              233.73     |
# | 453252 ‫بم - ماهان (سه‌راهي جيرفت - سه‌راهي راين)‬ |              228.876    |
# | 453115 ‫چترود - زرند (ده زيار)‬                  |              228.749    |
# | 453205 ‫سه راهي راين - کرمان(ماهان)‬             |              228.544    |
# | 453981 ‫پاريز - سيرجان‬                          |              221.174    |
# | 453953 ‫نيريز - سيرجان (سیرجان)‬                 |              220.108    |
# | 453753 ‫مهريز - انار (انار)‬                     |              207.528    |
# | 453931 ‫سيرجان - پاريز‬                          |              201.604    |
# | 454252 ‫زهکلوت - رودبار‬                         |              195.477    |
# | 453401 ‫بردسير - سيرجان‬                         |              192.634    |
# | 453353 ‫بافت - رابر (رابر)‬                      |              187.121    |
# | 454154 ‫هرات - شهربابک (شهربابک)‬                |              186.197    |
# | 454153 ‫جوزم - شهربابک (شهربابک)‬                |              166.514    |
# | 453301 ‫بافت - ارزوئيه (ارزوئيه)‬                |              161.997    |
# | 454103 ‫شهربابک - جوزم (شهربابک)‬                |              157.57     |
# | 453454 ‫بهرامجرد - نگار‬                         |              151.699    |
# | 454214 ‫کهنوج - منوجان‬                          |              146.536    |
# | 453654 ‫کهنوج - جيرف‬                            |              145.259    |
# | 453201 ‫راور - ديهوک (راور)‬                     |              139.505    |
# | 453352 ‫وکيل‌آباد - ارزوئيه (ارزوئيه)‬            |              137.323    |
# | 453757 ‫سرچشمه - رفسنجان‬                        |              136.161    |
# | 453351 ‫ارزوئيه - بافت (ارزوئيه)‬                |              135.234    |
# | 454157 ‫شهربابک - سرچشمه‬                        |              133.722    |
# | 454264 ‫منوجان - کهنوج‬                          |              133.666    |
# | 453244 ‫کمربندي باغين - جوپار‬                   |              132.521    |
# | 454221 ‫جيرفت - بافت‬                            |              132.483    |
# | 453154 ‫كرمان جوپار‬                             |              131.821    |
# | 454252 ‫گلمورتي - رودبار‬                        |              127.26     |
# | 453903 ‫سيرجان - نيريز (سیرجان)‬                 |              126.953    |
# | 453930 ‫شهربابک - سيرجان (شهربابک)‬              |              123.965    |
# | 454271 ‫بافت - جيرفت‬                            |              118.877    |
# | 453958 ‫شهربابک - سيرجان‬                        |              116.286    |
# | 453982 ‫سيرجان - بافت (بافت)‬                    |              108.625    |
# | 453160 ‫زرند - چترود (چترود)‬                    |              104.493    |
# | 453403 ‫کرمان - بافت (نگار)‬                     |              103.834    |
# | 453404 ‫نگار - بهرامجرد‬                         |              102.824    |
# | 453954 ‫بافت - سيرجان (سيرجان)‬                  |              102.367    |
# | 453904 ‫سيرجان - بافت (سيرجان)‬                  |              100.522    |
# | 453246 ‫کرمان - زنگي آباد‬                       |               94.9731   |
# | 454272 ‫عنبرآباد - جيرفت‬                        |               94.0219   |
# | 454269 ‫منوجان - قلعه گنج‬                       |               93.3441   |
# | 454213 ‫کهنوج - فارياب‬                          |               92.8852   |
# | 454263 ‫فارياب - کهنوج‬                          |               91.6421   |
# | 454202 ‫ رودبار - زهکلوت‬                        |               86.1744   |
# | 453251 ‫ديهوک - راور (راور)‬                     |               85.8307   |
# | 453104 ‫جوپار - کرمان‬                           |               80.9813   |
# | 453361 ‫ارزوييه - بافت‬                          |               78.7004   |
# | 453311 ‫بافت - ارزوييه‬                          |               76.4937   |
# | 453651 ‫باغين - بردسير‬                          |               75.0429   |
# | 453927 ‫کمربندي سيرجان - شهربابک‬                |               73.6606   |
# | 453294 ‫کمربندي جوپار - باغين‬                   |               72.48     |
# | 453852 ‫رفسنجان - زرند (داوران)‬                 |               68.5704   |
# | 453203 ‫کرمان - سيرچ‬                            |               67.3842   |
# | 453603 ‫جيرفت - دهبکري‬                          |               64.3691   |
# | 453451 ‫سيرجان - بردسير‬                         |               61.0775   |
# | 453113 ‫شهداد - نهبندان (شهداد)‬                 |               60.9662   |
# | 453662 ‫بافت - در بهشت‬                          |               58.5874   |
# | 453453 ‫بافت - کرمان (نگار)‬                     |               56.6015   |
# | 453932 ‫بافت - سيرجان (بافت)‬                    |               54.5475   |
# | 453302 ‫ارزوئيه - وکيل‌آباد (ارزوئيه)‬            |               52.9674   |
# | 454222 ‫جيرفت - عنبرآباد‬                        |               52.8566   |
# | 453567 ‫زاهدان - بم‬                             |               52.6786   |
# | 453802 ‫زرند - رفسنجان (داوران)‬                 |               52.0138   |
# | 453163 ‫نهبندان - شهداد (شهداد)‬                 |               50.5725   |
# | 453601 ‫بردسير - باغين‬                          |               48.3958   |
# | 454219 ‫قلعه گنج - منوجان‬                       |               45.5367   |
# | 454202 ‫رودبار - گلمورتي‬                        |               45.372    |
# | 453661 ‫فرودگاه - جيرفت‬                         |               45.2417   |
# | 453162 ‫جاده قديم کرمان - ماهان‬                 |               43.3435   |
# | 453612 ‫درب بهشت - بافت‬                         |               41.7786   |
# | 453669 ‫مردهک - عنبرآباد‬                        |               38.3679   |
# | 453705 ‫رفسنجان - نوق‬                           |               35.8814   |
# | 453662 ‫بافت - درب بهشت‬                         |               34.2015   |
# | 453703 ‫انار - مهريز (انار)‬                     |               34.0814   |
# | 453254 ‫ماهان - کرمان(هفت باغ علوي)‬             |               33.4974   |
# | 453611 ‫جيرفت - فرودگاه‬                         |               31.446    |
# | 453110 ‫چترود - زرند (چترود)‬                    |               31.1809   |
# | 453755 ‫نوق - رفسنجان‬                           |               30.1113   |
# | 453552 ‫بم - ايرانشهر (نرمانشير - بزمان)‬        |               29.3878   |
# | 453951 ‫حاجي آباد - سيرجان‬                      |               27.8163   |
# | 454266 ‫زيارتعلي - فارياب‬                       |               26.8015   |
# | 453610 ‫جيرفت - فارياب (کريم آباد)‬              |               25.099    |
# | 453253 ‫سيرج - کرمان‬                            |               24.3127   |
# | 453804 ‫زرند - بافق (زرند،محور سي ريز)‬          |               23.1685   |
# | 453610 ‫جيرفت - فارياب (خاتون‌آباد)‬              |               23.1284   |
# | 453619 ‫عنبرآباد - مردهک‬                        |               22.9831   |
# | 453164 ‫کوهپايه - کرمان‬                         |               22.4625   |
# | 454216 ‫فارياب - زيارتعلي‬                       |               21.1295   |
# | 453152 ‫ماهان - سه‌راهي راين (ماهان)‬             |               19.6776   |
# | 454218 ‫کهنوج - جيرفت‬                           |               18.7359   |
# | 453502 ‫ايرانشهر - بم (بزمان - نرمانشير)‬        |               17.9397   |
# | 453553 ‫فهرج - نرمانشير‬                         |               16.5398   |
# | 453114 ‫کرمان - کوهپايه‬                         |               14.9152   |
# | 454217 ‫بلوک - فارياب‬                           |               14.4191   |
# | 453112 ‫جاده قديم ماهان - كرمان‬                 |               14.0739   |
# | 453206 ‫باغين - کمربندي کرمان (سرآسياب)‬         |               13.0063   |
# | 453652 ‫کرمان - جيرفت (پليس‌راه)‬                 |               11.2714   |
# | 453296 ‫زنگي آباد - کرمان‬                       |               11.1656   |
# | 453503 ‫نرمانشير - فهرج‬                         |               10.6816   |
# | 453363 ‫جيرفت - رابر (قنات ملك)‬                 |               10.485    |
# | 453980 ‫سيرجان - شهربابک (شهربابک)‬              |               10.4561   |
# | 453854 ‫بافق - زرند (زرند،محور سي ريز)‬          |                9.46083  |
# | 453165 ‫زرند - چترود (ده زيار)‬                  |                8.93835  |
# | 454265 ‫ايرانشهر - زهکلوت‬                       |                8.77274  |
# | 454270 ‫ايرانشهر - قلعه گنج‬                     |                8.3124   |
# | 453851 ‫راور - چترود‬                            |                7.97549  |
# | 453801 ‫چترود - راور‬                            |                6.96083  |
# | 453620 ‫جيرفت - کرمان(جيرفت)‬                    |                6.92056  |
# | 453653 ‫دهبکري - جيرفت‬                          |                6.91753  |
# | 454220 ‫قلعه گنج - ايرانشهر‬                     |                6.51864  |
# | 453660 ‫فارياب - جيرفت (خاتون‌آباد)‬              |                6.36116  |
# | 453652 ‫کرمان - جيرفت (جبالبارز)‬                |                6.14424  |
# | 453660 ‫فارياب - جيرفت (کريم آباد)‬              |                5.74054  |
# | 453256 ‫کمربندي کرمان - باغين (سرآسياب)‬         |                5.6503   |
# | 454215 ‫زهکلوت - ايرانشهر‬                       |                5.28596  |
# | 453655 ‫بافت - جيرفت (پليس‌راه)‬                  |                4.84717  |
# | 453313 ‫رابر - جيرفت (قنات ملك)‬                 |                3.47887  |
# | 454267 ‫فارياب - بلوک‬                           |                3.11942  |
# | 453655 ‫بافت - جيرفت (دلفارد)‬                   |                3.05193  |
# | 453605 ‫جيرفت - بافت (پليس‌راه)‬                  |                2.16499  |
# | 453605 ‫جيرفت - بافت (دلفارد)‬                   |                1.58296  |
# | 453245 ‫کرمان - اختيار آباد‬                     |                0.676852 |
# | 453602 ‫جيرفت - کرمان (جبالبارز)‬                |                0.534983 |
# | 453602 ‫جيرفت - کرمان (پليس‌راه)‬                 |                0.510964 |
# | 453295 ‫اختيار آباد - کرمان‬                     |                0.409253 |

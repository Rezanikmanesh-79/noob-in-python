# %% [markdown]
# | Excel File                                                       |   Total Sum |
# |:-----------------------------------------------------------------|------------:|
# | Daily 453103 ‫کرمان - باغين‬ .xlsx                                 |      500124 |
# | Daily 453153 ‫باغين - کرمان‬ .xlsx                                 |      489264 |
# | Daily 453204 ‫کرمان - ماهان (هفت باغ علوي)‬ .xlsx                  |      418589 |
# | Daily 453958 ‫شهربابک - سيرجان‬ .xlsx                              |      396877 |
# | Daily 453254 ‫ماهان - کرمان(هفت باغ علوي)‬ .xlsx                   |      374434 |
# | Daily 453517 ‫بم - زاهدان‬ .xlsx                                   |      362782 |
# | Daily 453604 ‫جيرفت - کهنوج‬ .xlsx                                 |      340452 |
# | Daily 453903 ‫سيرجان - نيريز (سیرجان)‬ .xlsx                       |      339783 |
# | Daily 453930 ‫شهربابک - سيرجان (شهربابک - WIM)‬ .xlsx              |      337167 |
# | Daily 453654 ‫کهنوج - جيرفت‬ .xlsx                                 |      335553 |
# | Daily 453654 ‫کهنوج - جيرف‬ .xlsx                                  |      335221 |
# | Daily 453953 ‫نيريز - سيرجان (سیرجان)‬ .xlsx                       |      334821 |
# | Daily 453908 ‫سيرجان - شهربابک‬ .xlsx                              |      304549 |
# | Daily 453567 ‫زاهدان - بم‬ .xlsx                                   |      297499 |
# | Daily 453901 ‫سيرجان - حاجي آباد‬ .xlsx                            |      291485 |
# | Daily 453951 ‫حاجي آباد - سيرجان‬ .xlsx                            |      290648 |
# | Daily 453152 ‫ماهان - سه‌راهي راين (ماهان)‬ .xlsx                   |      275503 |
# | Daily 453753 ‫مهريز - انار (انار)‬ .xlsx                           |      275387 |
# | Daily 453751 ‫رفسنجان - باغين‬ .xlsx                               |      264212 |
# | Daily 453401 ‫بردسير - سيرجان‬ .xlsx                               |      254053 |
# | Daily 453651 ‫باغين - بردسير‬ .xlsx                                |      252655 |
# | Daily 453753 ‫يزد - انار‬ .xlsx                                    |      245714 |
# | Daily 453451 ‫سيرجان - بردسير‬ .xlsx                               |      244173 |
# | Daily 453102 ‫سه‌راهي راين - ماهان (ماهان)‬ .xlsx                   |      243833 |
# | Daily 453701 ‫باغين - رفسنجان‬ .xlsx                               |      242205 |
# | Daily 453703 ‫انار - يزد‬ .xlsx                                    |      235621 |
# | Daily 453703 ‫انار - مهريز (انار)‬ .xlsx                           |      233432 |
# | Daily 453620 ‫جيرفت - کرمان(جيرفت)‬ .xlsx                          |      232792 |
# | Daily 453555 ‫ماهان - بم (سه‌راهي جيرفت - بم)‬ .xlsx                |      229181 |
# | Daily 453247 ‫کرمان - هوتک (چترود)‬ .xlsx                          |      228497 |
# | Daily 453102 ‫جيرفت - ماهان‬ .xlsx                                 |      227936 |
# | Daily 453297 ‫هوتک (چترود) - کرمان‬ .xlsx                          |      226950 |
# | Daily 453505 ‫بم - ماهان (بم - سه‌راهي جيرفت)‬ .xlsx                |      226449 |
# | Daily 453702 ‫انار - رفسنجان‬ .xlsx                                |      219944 |
# | Daily 453295 ‫اختيار آباد - کرمان‬ .xlsx                           |      216244 |
# | Daily 453152 ‫ماهان - جيرفت‬ .xlsx                                 |      216084 |
# | Daily 453162 ‫جاده قديم کرمان - ماهان‬ .xlsx                       |      215909 |
# | Daily 453249 ‫کرمان - چترود‬ .xlsx                                 |      214563 |
# | Daily 454268 ‫جيرفت - کهنوج‬ .xlsx                                 |      212295 |
# | Daily 453245 ‫کرمان - اختيار آباد‬ .xlsx                           |      208080 |
# | Daily 453202 ‫ماهان - بم (سه‌راهي راين - سه‌راهي جيرفت)‬ .xlsx       |      207151 |
# | Daily 453165 ‫زرند - چترود (ده زيار)‬ .xlsx                        |      205766 |
# | Daily 453601 ‫بردسير - باغين‬ .xlsx                                |      205093 |
# | Daily 453953 ‫قطروئيه (شيراز) - سيرجان‬ .xlsx                      |      203742 |
# | Daily 453252 ‫بم - ماهان (سه‌راهي جيرفت - سه‌راهي راين)‬ .xlsx       |      202489 |
# | Daily 453160 ‫زرند - چترود (چترود)‬ .xlsx                          |      201906 |
# | Daily 453115 ‫چترود - زرند (ده زيار)‬ .xlsx                        |      196440 |
# | Daily 453110 ‫چترود - زرند (چترود)‬ .xlsx                          |      194730 |
# | Daily 453156 ‫جاده قديم کرمان - ماهان (قبل از دو راهي سيرچ)‬ .xlsx |      194131 |
# | Daily 453752 ‫رفسنجان - انار‬ .xlsx                                |      193580 |
# | Daily 454218 ‫کهنوج - جيرفت‬ .xlsx                                 |      190938 |
# | Daily 453903 ‫سيرجان - قطروئيه (شيراز)‬ .xlsx                      |      187467 |
# | Daily 453112 ‫جاده قديم ماهان - كرمان‬ .xlsx                       |      185819 |
# | Daily 454252 ‫زهکلوت - رودبار‬ .xlsx                               |      182270 |
# | Daily 454202 ‫ رودبار - زهکلوت‬ .xlsx                              |      181175 |
# | Daily 454153 ‫جوزم - شهربابک (شهربابک)‬ .xlsx                      |      179337 |
# | Daily 453101 ‫چترود - کرمان‬ .xlsx                                 |      172437 |
# | Daily 454103 ‫شهربابک - جوزم (شهربابک)‬ .xlsx                      |      166702 |
# | Daily 453980 ‫سيرجان - شهربابک (شهربابک)‬ .xlsx                    |      162233 |
# | Daily 453110 ‫چترود - زرند‬ .xlsx                                  |      161872 |
# | Daily 453160 ‫زرند - چترود‬ .xlsx                                  |      161451 |
# | Daily 453112 ‫جاده قديم ماهان - كرمان (سيلو)‬ .xlsx                |      161025 |
# | Daily 454252 ‫گلمورتي - رودبار‬ .xlsx                              |      154943 |
# | Daily 453555 ‫ماهان - بم (دوراهي دارزين)‬ .xlsx                    |      154332 |
# | Daily 454202 ‫رودبار - گلمورتي‬ .xlsx                              |      153367 |
# | Daily 453707 ‫رفسنجان - سرچشمه‬ .xlsx                              |      152506 |
# | Daily 453505 ‫بم (دوراهي دارزين) - ماهان‬ .xlsx                    |      151910 |
# | Daily 453980 ‫سيرجان - شهربابک (شهربابک - WIM)‬ .xlsx              |      151595 |
# | Daily 453930 ‫شهربابک - سيرجان (شهربابک)‬ .xlsx                    |      150953 |
# | Daily 453754 ‫شهربابک - انار(انار)‬ .xlsx                          |      148675 |
# | Daily 453151 ‫کرمان - چترود‬ .xlsx                                 |      146120 |
# | Daily 453299 ‫چترود - کرمان‬ .xlsx                                 |      146042 |
# | Daily 453705 ‫رفسنجان - نوق‬ .xlsx                                 |      145786 |
# | Daily 453156 ‫کرمان - ماهان (جاده قديم قبل ازسه راهي سيرچ)‬ .xlsx  |      144408 |
# | Daily 454272 ‫عنبرآباد - جيرفت‬ .xlsx                              |      144336 |
# | Daily 454264 ‫منوجان - کهنوج‬ .xlsx                                |      142609 |
# | Daily 453502 ‫ايرانشهر - بم (بزمان - نرمانشير)‬ .xlsx              |      142260 |
# | Daily 453704 ‫انار - شهربابک (انار)‬ .xlsx                         |      140896 |
# | Daily 453755 ‫نوق - رفسنجان‬ .xlsx                                 |      139131 |
# | Daily 453112 ‫ماهان - کرمان (سيلو)‬ .xlsx                          |      137419 |
# | Daily 453296 ‫زنگي آباد - کرمان‬ .xlsx                             |      137235 |
# | Daily 453101 ‫چترود - کرمان (پليس‌راه چترود)‬ .xlsx                 |      135439 |
# | Daily 4532111 ‫کرمان - چترود‬ .xlsx                                |      132508 |
# | Daily 454214 ‫کهنوج - منوجان‬ .xlsx                                |      131951 |
# | Daily 453704 ‫انار - سيرجان‬ .xlsx                                 |      131850 |
# | Daily 453757 ‫سرچشمه - رفسنجان‬ .xlsx                              |      129777 |
# | Daily 453246 ‫کرمان - زنگي آباد‬ .xlsx                             |      129413 |
# | Daily 453252 ‫بم - ماهان‬ .xlsx                                    |      128784 |
# | Daily 453202 ‫ماهان - بم‬ .xlsx                                    |      128222 |
# | Daily 454222 ‫جيرفت - عنبرآباد‬ .xlsx                              |      126788 |
# | Daily 453754 ‫سيرجان - انار‬ .xlsx                                 |      125558 |
# | Daily 453655 ‫بافت - جيرفت (پليس‌راه)‬ .xlsx                        |      118487 |
# | Daily 453154 ‫كرمان جوپار‬ .xlsx                                   |      116411 |
# | Daily 453205 ‫سه راهي راين - کرمان(ماهان)‬ .xlsx                   |      116069 |
# | Daily 453610 ‫جيرفت - فارياب (کريم آباد)‬ .xlsx                    |      115462 |
# | Daily 453610 ‫جيرفت - فارياب (خاتون‌آباد)‬ .xlsx                    |      112791 |
# | Daily 454254 ‫قلعه گنج - کهنوج‬ .xlsx                              |      112716 |
# | Daily 454253 ‫رودان - کهنوج‬ .xlsx                                 |      112448 |
# | Daily 453954 ‫بافت - سيرجان (سيرجان)‬ .xlsx                        |      111350 |
# | Daily 453652 ‫کرمان - جيرفت (پليس‌راه)‬ .xlsx                       |      110855 |
# | Daily 453927 ‫کمربندي سيرجان - شهربابک‬ .xlsx                      |      110794 |
# | Daily 453503 ‫نرمانشير - فهرج‬ .xlsx                               |      110640 |
# | Daily 454204 ‫کهنوج - قلعه گنج‬ .xlsx                              |      109976 |
# | Daily 453104 ‫جوپار - کرمان‬ .xlsx                                 |      109407 |
# | Daily 453660 ‫فارياب - جيرفت (خاتون‌آباد)‬ .xlsx                    |      109108 |
# | Daily 453904 ‫سيرجان - بافت (سيرجان)‬ .xlsx                        |      108515 |
# | Daily 453602 ‫جيرفت - کرمان (پليس‌راه)‬ .xlsx                       |      108509 |
# | Daily 453605 ‫جيرفت - بافت (پليس‌راه)‬ .xlsx                        |      108159 |
# | Daily 454203 ‫کهنوج - رودان‬ .xlsx                                 |      107135 |
# | Daily 453553 ‫فهرج - نرمانشير‬ .xlsx                               |      106846 |
# | Daily 453652 ‫کرمان - جيرفت (جبالبارز)‬ .xlsx                      |      106308 |
# | Daily 453852 ‫رفسنجان - زرند (داوران)‬ .xlsx                       |      105973 |
# | Daily 453164 ‫کوهپايه - کرمان‬ .xlsx                               |      105777 |
# | Daily 453605 ‫جيرفت - دلفارد‬ .xlsx                                |      103967 |
# | Daily 453954 ‫بافت - سيرجان‬ .xlsx                                 |      103204 |
# | Daily 453602 ‫جيرفت - کرمان (جبالبارز)‬ .xlsx                      |      102943 |
# | Daily 453655 ‫دلفارد - جيرفت‬ .xlsx                                |      102006 |
# | Daily 453802 ‫زرند - رفسنجان (داوران)‬ .xlsx                       |      101311 |
# | Daily 453655 ‫بافت - جيرفت (دلفارد)‬ .xlsx                         |      100823 |
# | Daily 453114 ‫کرمان - کوهپايه‬ .xlsx                               |       99731 |
# | Daily 453605 ‫جيرفت - بافت (دلفارد)‬ .xlsx                         |       98492 |
# | Daily 453552 ‫بم - ايرانشهر (نرمانشير - بزمان)‬ .xlsx              |       97946 |
# | Daily 453294 ‫کمربندي جوپار - باغين‬ .xlsx                         |       97906 |
# | Daily 453154 ‫کرمان - جوپار (قبل از دو راهي جوپار)‬ .xlsx          |       96973 |
# | Daily 453707 ‫رفسنجان - سرچشمه (بعدازکمربندي خروجي رفسنجان)‬ .xlsx |       96715 |
# | Daily 453954 ‫بافت - سيرجان (نجف شهر)‬ .xlsx                       |       96706 |
# | Daily 454103 ‫شهربابک - جوزم (خروجي شهربابک) ‬ .xlsx               |       96699 |
# | Daily 453612 ‫درب بهشت - بافت‬ .xlsx                               |       94406 |
# | Daily 454157 ‫شهربابک - سرچشمه‬ .xlsx                              |       93749 |
# | Daily 454107 ‫سرچشمه - شهربابک‬ .xlsx                              |       92207 |
# | Daily 453652 ‫جبالبارز - جيرفت‬ .xlsx                              |       92125 |
# | Daily 453662 ‫بافت - در بهشت‬ .xlsx                                |       91290 |
# | Daily 453244 ‫کمربندي باغين - جوپار‬ .xlsx                         |       89566 |
# | Daily 453660 ‫فارياب - جيرفت (کريم آباد)‬ .xlsx                    |       87537 |
# | Daily 453603 ‫جيرفت - دهبکري‬ .xlsx                                |       87371 |
# | Daily 453653 ‫دهبکري - جيرفت‬ .xlsx                                |       86418 |
# | Daily 453904 ‫سيرجان - بافت‬ .xlsx                                 |       85730 |
# | Daily 4532511 ‫چترود - کرمان‬ .xlsx                                |       84361 |
# | Daily 453602 ‫جيرفت - جبالبارز‬ .xlsx                              |       83975 |
# | Daily 453151 ‫کرمان - چترود (پليس‌راه چترود)‬ .xlsx                 |       82055 |
# | Daily 453982 ‫سيرجان - بافت (بافت)‬ .xlsx                          |       81143 |
# | Daily 453932 ‫بافت - سيرجان (بافت)‬ .xlsx                          |       80911 |
# | Daily 453904 ‫سيرجان (نجف شهر) - بافت‬ .xlsx                       |       80352 |
# | Daily 453552 ‫بزمان - رستم آباد‬ .xlsx                             |       79544 |
# | Daily 453502 ‫رستم آباد - بزمان‬ .xlsx                             |       79029 |
# | Daily 453403 ‫کرمان (نگار) - بافت‬ .xlsx                           |       77279 |
# | Daily 453803 ‫زرند - دشتخاک‬ .xlsx                                 |       77161 |
# | Daily 453853 ‫دشتخاک - زرند‬ .xlsx                                 |       76751 |
# | Daily 453161 ‫راين - سه‌راهي راين‬ .xlsx                            |       74070 |
# | Daily 453111 ‫سه‌راهي راين - راين‬ .xlsx                            |       73990 |
# | Daily 453311 ‫بافت - ارزوييه‬ .xlsx                                |       73621 |
# | Daily 454153 ‫جوزم - شهربابک (ورودي شهربابک) ‬ .xlsx               |       71742 |
# | Daily 453361 ‫ارزوييه - بافت‬ .xlsx                                |       71575 |
# | Daily 453351 ‫ارزوئيه - بافت (ارزوئيه)‬ .xlsx                      |       69516 |
# | Daily 453301 ‫بافت - ارزوئيه (ارزوئيه)‬ .xlsx                      |       69001 |
# | Daily 453253 ‫سيرج - کرمان‬ .xlsx                                  |       67924 |
# | Daily 454217 ‫بلوک - فارياب‬ .xlsx                                 |       67068 |
# | Daily 453403 ‫کرمان - بافت (نگار)‬ .xlsx                           |       66509 |
# | Daily 453649 ‫جيرفت - راين‬ .xlsx                                  |       65941 |
# | Daily 453699 ‫راين- جيرفت‬ .xlsx                                   |       65315 |
# | Daily 453619 ‫عنبرآباد - مردهک‬ .xlsx                              |       65100 |
# | Daily 453669 ‫مردهک - عنبرآباد‬ .xlsx                              |       64700 |
# | Daily 453111 ‫کرمان (دوراهي کرمان) - راين‬ .xlsx                   |       62615 |
# | Daily 4532101 ‫سه راهي راين - کرمان(ماهان)‬ .xlsx                  |       61844 |
# | Daily 453852 ‫رفسنجان - زرند ( ورودي داوران)‬ .xlsx                |       61712 |
# | Daily 453161 ‫راين - کرمان (دوراهي کرمان)‬ .xlsx                   |       61053 |
# | Daily 453453 ‫بافت - کرمان (نگار)‬ .xlsx                           |       60119 |
# | Daily 453981 ‫پاريز - سيرجان‬ .xlsx                                |       59959 |
# | Daily 453251 ‫ديهوک - راور‬ .xlsx                                  |       58990 |
# | Daily 453931 ‫سيرجان - پاريز‬ .xlsx                                |       58571 |
# | Daily 453201 ‫راور - ديهوک‬ .xlsx                                  |       57873 |
# | Daily 454267 ‫فارياب - بلوک‬ .xlsx                                 |       57777 |
# | Daily 453854 ‫بافق - زرند (زرند،محور سي ريز)‬ .xlsx                |       56659 |
# | Daily 453203 ‫کرمان - سيرچ‬ .xlsx                                  |       56401 |
# | Daily 453553 ‫فهرج - بم ‬ .xlsx                                    |       55690 |
# | Daily 453982 ‫سيرجان - بافت‬ .xlsx                                 |       55684 |
# | Daily 453503 ‫بم - فهرج ‬ .xlsx                                    |       55583 |
# | Daily 453353 ‫بافت - رابر (ورودي رابر )‬ .xlsx                     |       55148 |
# | Daily 453804 ‫زرند - بافق (زرند،محور سي ريز)‬ .xlsx                |       55122 |
# | Daily 453932 ‫بافت - سيرجان‬ .xlsx                                 |       55118 |
# | Daily 453804 ‫زرند - بافق (خروجي زرند)محورسي ريز‬ .xlsx            |       52288 |
# | Daily 453854 ‫بافق - زرند (ورودي زرند) محور سي ريز‬ .xlsx          |       51496 |
# | Daily 453302 ‫ارزوئيه - وکيل آباد (خروجي ارزوئيه) ‬ .xlsx          |       50888 |
# | Daily 453352 ‫وکيل آباد - ارزوئيه (ورودي ارزوئيه)‬ .xlsx           |       50326 |
# | Daily 453301 ‫بافت - ارزوئيه (خروجي ارزوئيه)‬ .xlsx                |       50170 |
# | Daily 453351 ‫ارزوئيه - بافت ( ورودي ارزوئيه)‬ .xlsx               |       50101 |
# | Daily 454104 ‫شهربابک - هرات (شهربابک)‬ .xlsx                      |       49437 |
# | Daily 453352 ‫وکيل‌آباد - ارزوئيه (ارزوئيه)‬ .xlsx                  |       48586 |
# | Daily 453353 ‫بافت - رابر (رابر)‬ .xlsx                            |       48549 |
# | Daily 453256 ‫کمربندي کرمان - باغين (سرآسياب)‬ .xlsx               |       48139 |
# | Daily 453251 ‫ديهوک - راور (راور)‬ .xlsx                           |       47501 |
# | Daily 453801 ‫چترود - راور‬ .xlsx                                  |       46818 |
# | Daily 453303 ‫رابر - بافت (خروجي رابر)‬ .xlsx                      |       46533 |
# | Daily 454154 ‫هرات - شهربابک (شهربابک)‬ .xlsx                      |       45907 |
# | Daily 453303 ‫رابر - بافت (رابر)‬ .xlsx                            |       45368 |
# | Daily 453611 ‫جيرفت - فرودگاه‬ .xlsx                               |       44127 |
# | Daily 453113 ‫شهداد - نهبندان (خروجي شهداد)‬ .xlsx                 |       43926 |
# | Daily 453201 ‫راور - ديهوک (راور)‬ .xlsx                           |       43821 |
# | Daily 453851 ‫راور - چترود‬ .xlsx                                  |       43598 |
# | Daily 453163 ‫نهبندان - شهداد (ورودي شهداد)‬ .xlsx                 |       43406 |
# | Daily 453206 ‫باغين - کمربندي کرمان (سرآسياب)‬ .xlsx               |       42853 |
# | Daily 453661 ‫فرودگاه - جيرفت‬ .xlsx                               |       42445 |
# | Daily 453610 ‫جيرفت - فارياب‬ .xlsx                                |       41669 |
# | Daily 453660 ‫فارياب - جيرفت‬ .xlsx                                |       41631 |
# | Daily 453803 ‫زرند –دشتخاک (قبل از سه راهي دشتخاک)‬ .xlsx          |       40203 |
# | Daily 454154 ‫هرات - شهربابک (ورودي شهربابک)‬ .xlsx                |       40069 |
# | Daily 454104 ‫شهر بابک –هرات (خروجي شهر بابک)‬ .xlsx               |       39701 |
# | Daily 453302 ‫ارزوئيه - وکيل‌آباد (ارزوئيه)‬ .xlsx                  |       38543 |
# | Daily 453853 ‫دشتخاک - زرند (بعد از سه راهي دشتخاک )‬ .xlsx        |       36566 |
# | Daily 453801 ‫زرند - راور‬ .xlsx                                   |       34107 |
# | Daily 454263 ‫فارياب - کهنوج‬ .xlsx                                |       33154 |
# | Daily 454213 ‫کهنوج - فارياب‬ .xlsx                                |       32304 |
# | Daily 453851 ‫راور - زرند‬ .xlsx                                   |       30032 |
# | Daily 4532510 ‫کمربندي کرمان - باغين (سرآسياب)‬ .xlsx              |       26365 |
# | Daily 454271 ‫بافت - جيرفت‬ .xlsx                                  |       24189 |
# | Daily 4532110 ‫باغين - کمربندي کرمان (سرآسياب)‬ .xlsx              |       24150 |
# | Daily 454221 ‫جيرفت - بافت‬ .xlsx                                  |       22877 |
# | Daily 453313 ‫رابر - جيرفت (قنات ملك)‬ .xlsx                       |       21745 |
# | Daily 453363 ‫جيرفت - رابر (قنات ملك)‬ .xlsx                       |       19606 |
# | Daily 453662 ‫بافت - درب بهشت‬ .xlsx                               |       17954 |
# | Daily 454266 ‫زيارتعلي - فارياب‬ .xlsx                             |       16390 |
# | Daily 454216 ‫فارياب - زيارتعلي‬ .xlsx                             |       16333 |
# | Daily 453163 ‫نهبندان - شهداد (شهداد)‬ .xlsx                       |       16008 |
# | Daily 453113 ‫شهداد - نهبندان (شهداد)‬ .xlsx                       |       15284 |
# | Daily 454215 ‫زهکلوت - ايرانشهر‬ .xlsx                             |       10962 |
# | Daily 454265 ‫ايرانشهر - زهکلوت‬ .xlsx                             |       10708 |
# | Daily 454269 ‫منوجان - قلعه گنج‬ .xlsx                             |        9008 |
# | Daily 454219 ‫قلعه گنج - منوجان‬ .xlsx                             |        8700 |
# | Daily 454220 ‫قلعه گنج - ايرانشهر‬ .xlsx                           |        8389 |
# | Daily 454270 ‫ايرانشهر - قلعه گنج‬ .xlsx                           |        3220 |

# %%
import matplotlib.pyplot as plt

# Extract Excel file names and total sums for plotting
excel_files = [item[0] for item in trends]
total_sums = [item[1] for item in trends]

plt.figure(figsize=(10, 6))
plt.bar(excel_files, total_sums, color='blue')
plt.xlabel('Excel Files')
plt.ylabel('Total Sum')
plt.title('Total Sum of Column 6 for Each Excel File')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
